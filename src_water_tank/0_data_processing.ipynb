# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os

# %%
outputpath='../data/water_tank_exps/'

# %% [markdown]
# ## build a dataframe

# %%
df = pd.DataFrame(columns=['action_mode', 'tg_threshold', 'water_tank_size', 'urbac'])

for f in os.listdir(outputpath):
    f1 = outputpath + f
    ds = xr.open_dataset(f1)['URBAN_AC'].sel(column=1,
                                             time = slice('2010', '2019')
                                             ).sum(dim='time').values/10*0.5/1000*500*500*3.14159/1000*0.75/3.6
    
    exp0 = float(f.split('_')[2])
    exp1 = float(f.split('_')[3])
    exp2 = float(f.split('_')[4].split('.nc')[0])
    ds = float(ds)
    df = pd.concat([df, pd.DataFrame({'action_mode': [exp0], 'tg_threshold': [exp1], 'water_tank_size': [exp2], 'urbac': [ds]})])
# Out:
# /tmp/ipykernel_21717/3862910136.py:13: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, pd.DataFrame({'action_mode': [exp0], 'tg_threshold': [exp1], 'water_tank_size': [exp2], 'urbac': [ds]})])

# %%
df.sort_values(by='urbac', ascending=False)
# Out:
#     action_mode  tg_threshold  water_tank_size        urbac
# 0      1.668374     64.444732         4.044359  1606.195068
# 0      3.857551     64.868780        12.744815  1606.187622
# 0      2.129575     64.483814         6.343111  1606.155396
# 0     12.967171     64.961255         0.295309  1606.120605
# 0      5.016914     64.729385        18.749818  1606.097778
# ..          ...           ...              ...          ...
# 0      7.242867     37.741602        18.947758  1512.826416
# 0     13.053062     36.847907        17.816920  1511.908569
# 0      8.836337     35.646085        16.157448  1510.762573
# 0     14.294029     35.474503        18.372591  1509.707397
# 0      8.783653     35.157471        19.210345  1504.347656
#
# [400 rows x 4 columns]

# %%
df.to_csv('water_tank_exps.csv', index=False)
